# %% [markdown]
# ## Week 2 Day 1
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">The OpenAI Agents SDK Docs</h2>
#             <span style="color:#00bfff;">The documentation on OpenAI Agents SDK is really clear and simple: <a href="https://openai.github.io/openai-agents-python/">https://openai.github.io/openai-agents-python/</a> and it's well worth a look.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
import os
import asyncio
from dotenv import load_dotenv
from openai import AsyncOpenAI
from agents import Agent, Runner, trace, set_default_openai_client, set_default_openai_api

# %%
# The usual starting point

load_dotenv(override=True)
# Out:
# True

# %%
# Get OpenRouter configuration from environment variables
base_url = os.getenv('OPENROUTER_BASE_URL')
api_key = os.getenv('OPENROUTER_API_KEY')

# Create AsyncOpenAI client with OpenRouter configuration
client = AsyncOpenAI(
    base_url=base_url,
    api_key=api_key
)

# %%
# Set the custom client as the default for the Agents SDK
set_default_openai_client(client)

# Use Chat Completions API (recommended for OpenRouter)
set_default_openai_api("chat_completions")

# %%
# Make an agent with name, instructions, model

agent = Agent(name="Jokester", instructions="You are a joke teller", model="litellm/openrouter/deepseek/deepseek-chat-v3-0324")

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output

with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\jharr\Documents\Apps\agents\.venv\Lib\site-packages\agents\extensions\models\litellm_model.py:13
#      12 try:
# ---> 13     import litellm
#      14 except ImportError as _e:
#
# ModuleNotFoundError: No module named 'litellm'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 4
#       1 # Run the joke with Runner.run(agent, prompt) then print final_output
#       3 with trace("Telling a joke"):
# ----> 4     result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
#       5     print(result.final_output)
#
# File c:\Users\jharr\Documents\Apps\agents\.venv\Lib\site-packages\agents\run.py:199, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config, previous_response_id)
#     172 """Run a workflow starting at the given agent. The agent will run in a loop until a final
#     173 output is generated. The loop runs like so:
#     174 1. The agent is invoked with the given input.
#    (...)    196     agent. Agents may perform handoffs, so we don't know the specific type of the output.
#     197 """
#     198 runner = DEFAULT_AGENT_RUNNER
# --> 199 return await runner.run(
#     200     starting_agent,
#     201     input,
#     202     context=context,
#     203     max_turns=max_turns,
#     204     hooks=hooks,
#     205     run_config=run_config,
#     206     previous_response_id=previous_response_id,
#     207 )
#
# File c:\Users\jharr\Documents\Apps\agents\.venv\Lib\site-packages\agents\run.py:395, in AgentRunner.run(self, starting_agent, input, **kwargs)
#     390 logger.debug(
#     391     f"Running agent {current_agent.name} (turn {current_turn})",
#     392 )
#     394 if current_turn == 1:
# --> 395     input_guardrail_results, turn_result = await asyncio.gather(
#     396         self._run_input_guardrails(
#     397             starting_agent,
#     398             starting_agent.input_guardrails
#     399             + (run_config.input_guardrails or []),
#     400             copy.deepcopy(input),
#     401             context_wrapper,
#     402         ),
#     403         self._run_single_turn(
#     404             agent=current_agent,
#     405             all_tools=all_tools,
#     406             original_input=original_input,
#     407             generated_items=generated_items,
#     408             hooks=hooks,
#     409             context_wrapper=context_wrapper,
#     410             run_config=run_config,
#     411             should_run_agent_start_hooks=should_run_agent_start_hooks,
#     412             tool_use_tracker=tool_use_tracker,
#     413             previous_response_id=previous_response_id,
#     414         ),
#     415     )
#     416 else:
#     417     turn_result = await self._run_single_turn(
#     418         agent=current_agent,
#     419         all_tools=all_tools,
#    (...)    427         previous_response_id=previous_response_id,
#     428     )
#
# File c:\Users\jharr\Documents\Apps\agents\.venv\Lib\site-packages\agents\run.py:905, in AgentRunner._run_single_turn(cls, agent, all_tools, original_input, generated_items, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, previous_response_id)
#     902 input = ItemHelpers.input_to_new_input_list(original_input)
#     903 input.extend([generated_item.to_input_item() for generated_item in generated_items])
# --> 905 new_response = await cls._get_new_response(
#     906     agent,
#     907     system_prompt,
#     908     input,
#     909     output_schema,
#     910     all_tools,
#     911     handoffs,
#     912     context_wrapper,
#     913     run_config,
#     914     tool_use_tracker,
#     915     previous_response_id,
#     916     prompt_config,
#     917 )
#     919 return await cls._get_single_step_result_from_response(
#     920     agent=agent,
#     921     original_input=original_input,
#    (...)    930     tool_use_tracker=tool_use_tracker,
#     931 )
#
# File c:\Users\jharr\Documents\Apps\agents\.venv\Lib\site-packages\agents\run.py:1062, in AgentRunner._get_new_response(cls, agent, system_prompt, input, output_schema, all_tools, handoffs, context_wrapper, run_config, tool_use_tracker, previous_response_id, prompt_config)
#    1047 @classmethod
#    1048 async def _get_new_response(
#    1049     cls,
#    (...)   1060     prompt_config: ResponsePromptParam | None,
#    1061 ) -> ModelResponse:
# -> 1062     model = cls._get_model(agent, run_config)
#    1063     model_settings = agent.model_settings.resolve(run_config.model_settings)
#    1064     model_settings = RunImpl.maybe_reset_tool_choice(agent, tool_use_tracker, model_settings)
#
# File c:\Users\jharr\Documents\Apps\agents\.venv\Lib\site-packages\agents\run.py:1118, in AgentRunner._get_model(cls, agent, run_config)
#    1115 elif isinstance(agent.model, Model):
#    1116     return agent.model
# -> 1118 return run_config.model_provider.get_model(agent.model)
#
# File c:\Users\jharr\Documents\Apps\agents\.venv\Lib\site-packages\agents\models\multi_provider.py:144, in MultiProvider.get_model(self, model_name)
#     142     return provider.get_model(model_name)
#     143 else:
# --> 144     return self._get_fallback_provider(prefix).get_model(model_name)
#
# File c:\Users\jharr\Documents\Apps\agents\.venv\Lib\site-packages\agents\models\multi_provider.py:125, in MultiProvider._get_fallback_provider(self, prefix)
#     123     return self._fallback_providers[prefix]
#     124 else:
# --> 125     self._fallback_providers[prefix] = self._create_fallback_provider(prefix)
#     126     return self._fallback_providers[prefix]
#
# File c:\Users\jharr\Documents\Apps\agents\.venv\Lib\site-packages\agents\models\multi_provider.py:113, in MultiProvider._create_fallback_provider(self, prefix)
#     111 def _create_fallback_provider(self, prefix: str) -> ModelProvider:
#     112     if prefix == "litellm":
# --> 113         from ..extensions.models.litellm_provider import LitellmProvider
#     115         return LitellmProvider()
#     116     else:
#
# File c:\Users\jharr\Documents\Apps\agents\.venv\Lib\site-packages\agents\extensions\models\litellm_provider.py:2
#       1 from ...models.interface import Model, ModelProvider
# ----> 2 from .litellm_model import LitellmModel
#       4 DEFAULT_MODEL: str = "gpt-4.1"
#       7 class LitellmProvider(ModelProvider):
#
# File c:\Users\jharr\Documents\Apps\agents\.venv\Lib\site-packages\agents\extensions\models\litellm_model.py:15
#      13     import litellm
#      14 except ImportError as _e:
# ---> 15     raise ImportError(
#      16         "`litellm` is required to use the LitellmModel. You can install it via the optional "
#      17         "dependency group: `pip install 'openai-agents[litellm]'`."
#      18     ) from _e
#      20 from openai import NOT_GIVEN, AsyncStream, NotGiven
#      21 from openai.types.chat import ChatCompletionChunk, ChatCompletionMessageToolCall
#
# ImportError: `litellm` is required to use the LitellmModel. You can install it via the optional dependency group: `pip install 'openai-agents[litellm]'`.
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: sk-or-v1*************************************************************8cbf. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
