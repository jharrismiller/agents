# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-or-v1

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)
OPENROUTER_BASE_URL = os.getenv('OPENROUTER_BASE_URL')
openrouter = OpenAI(base_url=OPENROUTER_BASE_URL, api_key=openai_api_key)

# %%
import json

# %%
# Create a list of messages in the familiar OpenAI format
OPENROUTER_DEFAULT_Model =  os.getenv('OPENROUTER_DEFAULT_Model')

# %%
print (OPENROUTER_DEFAULT_Model)
# Out:
# { "id": "meta-llama/llama-4-maverick-17b-128e-instruct:free", "name": "Meta: Llama 4 Maverick (free)"}

# %%
openrouter_model = json.loads(OPENROUTER_DEFAULT_Model).get("id")
messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openrouter.chat.completions.create(
    model=openrouter_model,
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# The answer to 2 + 2 is 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openrouter.chat.completions.create(
    model=openrouter_model,
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# A certain five-digit number has the following properties: its digits are all different, it is divisible by 9, its first digit is 4, and when its digits are reversed, the resulting number is divisible by 6. What is this number?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again
print (messages)
response = openrouter.chat.completions.create(
    model="deepseek/deepseek-r1:free",
    messages=messages
)


answer = response.choices[0].message.content
print(answer)
# Out:
# Given a five-digit number 4ABCD with the following properties:
# 1. All digits are different.
# 2. The number is divisible by 9.
# 3. The first digit is 4.
# 4. When the digits are reversed, the resulting number is divisible by 6.
#
# Key steps:
# 1. The number is in the range 40000 to 49999.
# 2. Divisibility by 9 implies the sum of its digits (4 + A + B + C + D) is a multiple of 9.
# 3. Reversing the digits results in a number divisible by 6 (must be even and the sum of digits divisible by 3).
# 4. Since the sum of the digits of the original number is divisible by 9, the reversed number's sum (same as original) is also divisible by 3, ensuring divisibility by 3. The original number ends with 4, ensuring the reversed number starts with 4, making it even.
#
# Possible digit sums for divisibility by 9 are 18 or 27 (since 9 is too low and 27 is possible with maximum digit sum 34).
#
# For sum 18:
# - A + B + C + D = 14
# - valid combinations: 0, 1, 5, 8; 0, 1, 6, 7; 0, 2, 5, 7
#
# Checking combinations:
# - 41058: digits 4, 1, 0, 5, 8 are unique, sum 18. Reverse 85014 divisible by 6.
# - 41256: digits 4, 1, 2, 5, 6 are unique, sum 18. Reverse 65214 divisible by 6.
# - 41067: digits 4, 1, 0, 6, 7 are unique, sum 18. Reverse 76014 divisible by 6.
#
# For sum 27:
# - A + B + C + D = 23
# - valid combinations: 9, 8, 6, 0; 9, 7, 5, 2
#
# Checking combinations:
# - 40689: digits 4, 0, 6, 8, 9 are unique, sum 27. Reverse 98604 divisible by 6.
# - 49752: digits 4, 9, 7, 5, 2 are unique, sum 27. Reverse 25794 divisible by 6.
#
# Given the problem states "a certain five-digit number", but multiple solutions exist. However, considering common problem solutions and logical deductions, the answer chosen is 41058.
#
# \boxed{41058}

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Given a five-digit number 4ABCD with the following properties:
# 1. All digits are different.
# 2. The number is divisible by 9.
# 3. The first digit is 4.
# 4. When the digits are reversed, the resulting number is divisible by 6.
#
# Key steps:
# 1. The number is in the range 40000 to 49999.
# 2. Divisibility by 9 implies the sum of its digits (4 + A + B + C + D) is a multiple of 9.
# 3. Reversing the digits results in a number divisible by 6 (must be even and the sum of digits divisible by 3).
# 4. Since the sum of the digits of the original number is divisible by 9, the reversed number's sum (same as original) is also divisible by 3, ensuring divisibility by 3. The original number ends with 4, ensuring the reversed number starts with 4, making it even.
#
# Possible digit sums for divisibility by 9 are 18 or 27 (since 9 is too low and 27 is possible with maximum digit sum 34).
#
# For sum 18:
# - A + B + C + D = 14
# - valid combinations: 0, 1, 5, 8; 0, 1, 6, 7; 0, 2, 5, 7
#
# Checking combinations:
# - 41058: digits 4, 1, 0, 5, 8 are unique, sum 18. Reverse 85014 divisible by 6.
# - 41256: digits 4, 1, 2, 5, 6 are unique, sum 18. Reverse 65214 divisible by 6.
# - 41067: digits 4, 1, 0, 6, 7 are unique, sum 18. Reverse 76014 divisible by 6.
#
# For sum 27:
# - A + B + C + D = 23
# - valid combinations: 9, 8, 6, 0; 9, 7, 5, 2
#
# Checking combinations:
# - 40689: digits 4, 0, 6, 8, 9 are unique, sum 27. Reverse 98604 divisible by 6.
# - 49752: digits 4, 9, 7, 5, 2 are unique, sum 27. Reverse 25794 divisible by 6.
#
# Given the problem states "a certain five-digit number", but multiple solutions exist. However, considering common problem solutions and logical deductions, the answer chosen is 41058.
#
# \boxed{41058}

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Identity 3 AI agentic oppourtunities for a new business or to improve an existing buiness."}]

# Then make the first call:

response = openrouter.chat.completions.create(
    model="google/gemini-2.0-flash-001",
    messages=messages
)


# Then read the business idea:
business_idea = response.choices[0].message.content


# And repeat! In the next message, include the business idea within the message
# Out:
# <IPython.core.display.Markdown object>

# %%
display (Markdown(business_idea))
# Out:
# Here are three AI agentic opportunities for a new or existing business, focusing on diverse areas:
#
# **1. Agentic Personalized Education/Training (New or Existing Business Improvement):**
#
# *   **Concept:** Develop an AI agent that acts as a personalized learning assistant, adapting to individual student/employee needs, learning styles, and progress.
# *   **Functionality:**
#     *   **Skill Gap Analysis:** Assesses current knowledge and identifies skill gaps.
#     *   **Curriculum Tailoring:** Generates a personalized learning path with relevant resources (articles, videos, exercises) based on the assessment and learning goals.
#     *   **Adaptive Difficulty:** Adjusts the difficulty of learning materials and assessments based on real-time performance.
#     *   **Motivational Support:** Provides encouragement, reminders, and celebrates milestones to maintain engagement.
#     *   **Automated Feedback & Coaching:** Provides instant feedback on exercises and assignments, offering targeted coaching on areas for improvement.
#     *   **Question Answering & Clarification:** Answers questions and clarifies concepts in a way that is understandable to the individual learner.
# *   **Business Opportunities:**
#     *   **New Startup:** Focus on a specific industry (e.g., software engineering, marketing, finance) or a broad skill set (e.g., project management, data analysis).
#     *   **Existing Training Company Improvement:** Augment current course offerings with personalized AI assistants.  This could dramatically increase completion rates and learner satisfaction.
#     *   **Corporate Training Integration:**  Offer the agent as a solution for onboarding new employees or upskilling current staff.
# *   **Agentic Nature:** The AI is agentic because it's not just providing information; it's actively guiding the learning process, making decisions about what to present and how to present it, all with the goal of maximizing individual learning outcomes *without constant human intervention*.
#
# **2. Agentic Supply Chain Optimization (Existing Business Improvement):**
#
# *   **Concept:** Implement an AI agent that autonomously manages and optimizes a company's supply chain from end to end.
# *   **Functionality:**
#     *   **Demand Forecasting:** Predicts future demand with high accuracy, incorporating market trends, seasonality, and external factors.
#     *   **Inventory Management:** Automatically adjusts inventory levels based on demand forecasts, lead times, and storage costs.
#     *   **Supplier Selection & Negotiation:** Identifies and evaluates potential suppliers based on price, quality, reliability, and ethical considerations.  May even automate contract negotiations.
#     *   **Logistics Optimization:** Routes shipments, selects carriers, and manages delivery schedules to minimize costs and transit times.
#     *   **Risk Assessment & Mitigation:** Identifies potential disruptions in the supply chain (e.g., natural disasters, political instability, supplier bankruptcies) and proactively develops mitigation strategies.
#     *   **Automated Issue Resolution:** Resolves common supply chain issues (e.g., order delays, quality defects) without human intervention.
# *   **Business Opportunities:**
#     *   **Supply Chain Consulting Improvement:** Provide AI-powered optimization services as part of your consulting offering.
#     *   **Manufacturing/Retail Integration:** Dramatically improve efficiency and reduce costs within a manufacturing or retail company.
#     *   **Software-as-a-Service (SaaS) offering:** Package the AI agent as a subscription-based service for other businesses.
# *   **Agentic Nature:** The AI is agentic because it's not just tracking data; it's actively making decisions about inventory, procurement, logistics, and risk management, all with the goal of optimizing the entire supply chain *without requiring constant human oversight*.  It takes initiative to resolve problems proactively.
#
# **3. AI-Powered Personalized Financial Advisor (New Startup):**
#
# *   **Concept:** Develop an AI agent that provides personalized financial advice and management, accessible to a wider audience regardless of wealth.
# *   **Functionality:**
#     *   **Financial Goal Setting:** Helps users define their financial goals (e.g., retirement, home purchase, debt repayment).
#     *   **Risk Assessment:** Assesses the user's risk tolerance and financial situation.
#     *   **Investment Portfolio Creation & Management:** Creates a diversified investment portfolio based on the user's goals, risk tolerance, and financial situation. Automatically rebalances the portfolio to maintain the desired asset allocation.
#     *   **Budgeting & Expense Tracking:** Tracks income and expenses, identifies areas for savings, and helps users create a budget.
#     *   **Debt Management:** Provides personalized strategies for paying down debt.
#     *   **Tax Optimization:** Identifies tax-saving opportunities.
#     *   **Proactive Recommendations:**  Suggests actionable steps to improve the user's financial situation, such as increasing contributions to retirement accounts, refinancing debt, or adjusting investment allocations.
# *   **Business Opportunities:**
#     *   **Direct-to-consumer financial advisor:** Offer accessible, low-cost financial advice to individuals.
#     *   **Partnership with Financial Institutions:** Integrate the AI agent into existing banking or investment platforms.
# *   **Agentic Nature:** The AI is agentic because it doesn't just provide data or calculations. It acts as a financial advisor, making decisions about investments, budgeting, and debt management, aiming to help users achieve their financial goals *independently and proactively*. It learns from the user's behavior and market trends to continuously refine its recommendations.
#
# In all three examples, the agentic nature of the AI is crucial.  It's not simply automating tasks; it's leveraging data and algorithms to make informed decisions and take actions that directly benefit the user or the business, reducing the need for constant human supervision and intervention.  This leads to greater efficiency, personalization, and ultimately, better outcomes.

# %%
messages = [{"role": "user", "content": "What is a pain point in the Manufacturing/Retail industry that would benefir from Agentic AI?"}]

# Then make the first call:

response = openrouter.chat.completions.create(
    model="openai/gpt-4o-mini",
    messages=messages
)

display(Markdown(response.choices[0].message.content))
# Out:
# One significant pain point in the Manufacturing/Retail industry that would benefit from Agentic AI is inventory management.
#
# **Pain Point: Inventory Management**
#
# **Challenges:**
# - **Overstock and Stockouts:** Companies often struggle to maintain the right balance of inventory. Overstock can lead to increased holding costs and waste, while stockouts can result in lost sales and dissatisfied customers.
# - **Demand Forecasting:** Accurate forecasting of demand is notoriously difficult, leading to either excess inventory or insufficient stock to meet customer needs.
# - **Supply Chain Disruptions:** Changes in supply chain dynamics, such as supplier delays or variability in lead times, can complicate inventory management efforts.
# - **Complexity of Products:** With numerous SKUs (stock-keeping units), managing inventory becomes more complex, requiring real-time data and insights.
#
# **How Agentic AI Can Help:**
# 1. **Real-Time Data Analysis:** Agentic AI can analyze real-time sales data, market trends, and consumer behavior to provide more accurate demand forecasting, allowing manufacturers and retailers to adjust inventory levels proactively.
#
# 2. **Automated Replenishment:** AI-driven systems can automate the reorder process, ensuring optimal stock levels are maintained by predicting when products need restocking based on sales velocity and inventory turnover rates.
#
# 3. **Dynamic Pricing and Promotion Strategies:** AI can help adjust pricing and promotions based on inventory levels and demand forecasts, minimizing excess stock while maximizing revenue.
#
# 4. **Supply Chain Optimization:** AI can analyze the entire supply chain, identifying potential disruptions and providing alternative sourcing options, thereby improving lead times and reducing the risk of stockouts.
#
# 5. **Enhanced Visibility and Collaboration:** Agentic AI can facilitate better communication and collaboration between various stakeholders (suppliers, distributors, retailers) by providing a centralized data platform that enables real-time decision-making.
#
# By implementing Agentic AI in inventory management, companies in the Manufacturing/Retail industry can enhance efficiency, reduce costs, improve customer satisfaction, and ultimately drive better business outcomes.

# %%
messages = [{"role": "user", "content": "Propose an Agentic AI solution to the issue of Overstock and Stockouts in the Manufacturing/Retail industry"}]

# Then make the first call:

response = openrouter.chat.completions.create(
    model="google/gemini-2.5-flash-preview-05-20:thinking",
    messages=messages
)

display(Markdown(response.choices[0].message.content))
# Out:
# The persistent challenges of overstock and stockouts severely impact profitability, customer satisfaction, and operational efficiency in the manufacturing and retail sectors. Overstock ties up capital, incurs storage costs, and leads to write-offs, while stockouts result in lost sales, frustrated customers, and damaged brand reputation.
#
# An **Agentic AI** solution offers a powerful paradigm shift by deploying autonomous, goal-directed AI agents that can perceive, reason, act, and learn within the dynamic supply chain ecosystem. Instead of a single monolithic AI, this approach leverages a swarm of specialized agents collaborating towards an optimized inventory state.
#
# ---
#
# ## Agentic AI Solution for Overstock and Stockouts
#
# **Core Principle:** A network of intelligent, autonomous AI agents continuously monitors, analyzes, predicts, and optimizes inventory levels across the entire value chain – from raw material sourcing and manufacturing to warehousing and retail shelves.
#
# ### 1. The Agentic Architecture: A Swarm of Specialized AI Agents
#
# The solution would operate as a distributed multi-agent system, each agent having a specific role, capabilities, and objectives, all contributing to the overarching goal of inventory optimization.
#
# **Key Agent Types:**
#
# 1.  **Market & Demand Intelligence Agent (MDIA):**
#     *   **Perceives:** Real-time POS data, e-commerce traffic, social media trends, competitor pricing/promotions, macroeconomic indicators (inflation, consumer confidence), weather patterns (for relevant products).
#     *   **Reasons:** Applies advanced forecasting models (time series, deep learning, causal models) to predict demand fluctuations, seasonality, trends, and promotional impacts. Identifies anomalies (flash sales, sudden drops).
#     *   **Acts:** Publishes dynamic, granular demand forecasts (SKU-level, location-level, hourly/daily/weekly) to the Inventory Optimization Agent and Production Planning Agent. Flags emerging trends or potential disruptions.
#     *   **Learns:** Continuously refines forecasting models based on actual sales data and prediction errors. Learns from the effectiveness of past promotions.
#
# 2.  **Inventory Optimization Agent (IOA):**
#     *   **Perceives:** Current inventory levels (raw materials, WIP, finished goods) across all locations (factories, warehouses, stores), MDIA forecasts, Production Planning Agent schedules, Supplier Relationship Agent updates.
#     *   **Reasons:** Calculates optimal reorder points, safety stock levels, and replenishment quantities for each SKU at each location, considering lead times, demand variability, holding costs, and target service levels. Uses mathematical optimization (linear programming, simulation).
#     *   **Acts:** Generates purchase requisitions for raw materials, inter-warehouse transfer orders, and store replenishment orders. Flags slow-moving or excess inventory to the Pricing & Promotion Agent.
#     *   **Learns:** Adjusts optimal stock parameters based on observed holding costs, lost sales from stockouts, and lead time accuracy.
#
# 3.  **Production Planning Agent (PPA) - *For Manufacturing:* **
#     *   **Perceives:** MDIA demand forecasts, IOA raw material needs, current production line capacity, machine uptime, maintenance schedules, labor availability, bill of materials (BOM).
#     *   **Reasons:** Schedules production runs, optimizes batch sizes, balances production lines to meet forecasted demand while minimizing changeover costs and maximizing throughput. Prioritizes urgent orders.
#     *   **Acts:** Releases production orders to the factory floor, requests raw materials from suppliers (via SRA), and updates finished goods availability to IOA.
#     *   **Learns:** Optimizes scheduling algorithms based on actual production times, defect rates, and bottleneck identification.
#
# 4.  **Supplier Relationship Agent (SRA):**
#     *   **Perceives:** Raw material demand from PPA/IOA, supplier lead times, historical supplier reliability, quality control data, geopolitical news (supply chain risks).
#     *   **Reasons:** Evaluates supplier performance, identifies potential supply chain bottlenecks or disruptions, suggests alternative suppliers. Negotiates (or supports human negotiation) for better terms.
#     *   **Acts:** Places purchase orders with selected suppliers, monitors order status, and alerts IOA/PPA about any delays or issues. Proactively re-routes or re-orders if a risk is detected.
#     *   **Learns:** Refines supplier reliability scores and preferred supplier lists based on real-world performance.
#
# 5.  **Logistics & Fulfillment Agent (LFA):**
#     *   **Perceives:** Inventory transfer requests from IOA, warehouse capacity, transport availability, shipping costs, delivery times, real-time traffic/weather conditions.
#     *   **Reasons:** Optimizes routing, selects shipping methods (truck, rail, air), consolidates shipments, and manages last-mile delivery to minimize costs and maximize delivery speed. Predicts potential delivery delays.
#     *   **Acts:** Books transport, generates shipping labels, tracks shipments, and provides real-time updates to relevant agents (e.g., IOA for incoming stock updates).
#     *   **Learns:** Optimizes routing algorithms based on actual delivery times and cost efficiency.
#
# 6.  **Pricing & Promotion Agent (PPA) - *For Retail:* **
#     *   **Perceives:** IOA flagging of overstock/slow-moving items, MDIA demand elasticity, competitor pricing, customer segmentation data.
#     *   **Reasons:** Recommends dynamic pricing adjustments or targeted promotional campaigns to clear excess inventory or boost demand for specific products without negatively impacting profit margins.
#     *   **Acts:** Sends pricing updates to POS systems/e-commerce platforms, triggers marketing automation for promotions.
#     *   **Learns:** Optimizes pricing strategies based on actual sales response and profit generated.
#
# 7.  **Financial & Risk Assessment Agent (FRAA):**
#     *   **Perceives:** Data from all other agents regarding inventory levels, production costs, sales revenue, promotional costs, supplier invoices, potential supply disruptions.
#     *   **Reasons:** Calculates the financial impact of various scenarios (e.g., cost of holding excess vs. lost sales from stockouts), assesses overall supply chain risk, and ensures compliance.
#     *   **Acts:** Provides financial projections and risk assessments to a central dashboard for human oversight. Can trigger alerts for significant deviations from financial targets.
#     *   **Learns:** Improves risk models based on the outcomes of past disruptions and financial performance.
#
# ### 2. How the Agentic System Works (Continuous Loop):
#
# 1.  **Perception & Data Ingestion:** All agents continuously ingest massive amounts of real-time data from internal systems (ERP, WMS, POS, MES), external sources (market data feeds, weather APIs, news), and sensor data (IoT in warehouses/factories).
# 2.  **Analysis & Prediction:** Agents (especially MDIA, SRA) use their specialized ML models to analyze data, identify patterns, predict future events (demand, lead times, disruptions), and assess risks.
# 3.  **Planning & Optimization:** Based on predictions and current states, agents (IOA, PPA, LFA) run rapid simulations and optimization algorithms to determine the best course of action (e.g., ideal order quantities, production schedules, transport routes).
# 4.  **Decision & Collaboration:** Agents communicate and negotiate (via an internal message bus or shared ontology). For example, IOA requests production from PPA, which checks with SRA for raw material availability. Conflicts (e.g., PPA capacity vs. MDIA demand) are resolved autonomously through predefined negotiation protocols or escalated to a human "meta-agent" for review.
# 5.  **Action & Execution:** Agents trigger actions through integrations with existing systems (ERP for POs, WMS for inventory transfers, MES for production start, POS for price changes). Some actions might require human approval, especially in early deployment stages.
# 6.  **Learning & Adaptation:** Every action's outcome is fed back into the system. Agents continuously update their models, improve their predictive accuracy, and refine their decision-making algorithms through reinforcement learning and other adaptive techniques. They learn from successes and failures, becoming more effective over time.
#
# ### 3. Key Benefits of the Agentic Approach:
#
# *   **Proactive & Predictive:** Moves beyond reactive adjustments to anticipate issues before they occur.
# *   **Dynamic & Adaptive:** Responds to real-time changes in demand, supply, and market conditions with unprecedented speed.
# *   **Reduced Overstock:** Minimizes holding costs, obsolescence, and write-offs by precisely matching supply to demand.
# *   **Reduced Stockouts:** Maximizes sales opportunities and customer satisfaction by ensuring product availability.
# *   **Enhanced Cash Flow:** Frees up capital tied in excess inventory and improves sales velocity.
# *   **Improved Efficiency:** Automates complex planning and execution tasks, reducing manual errors and operational overhead.
# *   **Increased Resilience:** Identifies and mitigates supply chain risks, allowing for rapid course correction during disruptions.
# *   **Optimized Profitability:** Balances inventory costs with sales revenue potential through enlightened decision-making.
# *   **Explainability (XAI):** While autonomous, each agent's decisions can be logged and, to an extent, "interrogated" to understand the rationale, aiding human trust and oversight.
#
# ### 4. Implementation Considerations & Challenges:
#
# *   **Data Infrastructure:** Requires robust real-time data pipelines, data cleansing, and a unified data model across disparate systems.
# *   **Integration Complexity:** Integrating with existing ERP, WMS, CRM, POS, and MES systems will be a significant undertaking.
# *   **Trust and Oversight:** Initial human supervision of agent decisions will be crucial. A clear human-in-the-loop mechanism is essential, with agents flagging "high-risk" decisions for review.
# *   **Computational Resources:** Running complex simulations and ML models for numerous agents in real-time requires substantial computing power.
# *   **Security:** Robust cybersecurity measures are paramount given the sensitive nature of the data and autonomous actions.
# *   **Phased Rollout:** Starting with specific product lines or regions, demonstrating ROI, and then expanding will be a practical approach.
# *   **Ethical Considerations:** Potential impact on job roles, though the focus is on augmenting human capabilities, not replacing them entirely.
#
# By embracing an Agentic AI solution, manufacturing and retail companies can transform their supply chains from reactive operations to highly intelligent, self-optimizing ecosystems, leading to significant competitive advantages and sustainable growth.
